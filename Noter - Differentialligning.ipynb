# %% [markdown]
# # Differentialligninger

# %%
import numpy as np
from scipy.integrate import odeint
#løsning af differentialligning
y_first_t=1
ts=[0,3]
#evt.
ts1 = np.arange(4)
#odeint(fkt,startværdi for afhængig variabel, interval for uafhængig variabel(liste[]))
dydt = odeint(lambda y,t: 0.9*y**2*np.cos(t),y_first_t,ts1)
dydt
# Out:
# array([[1.        ],
#        [4.1207187 ],
#        [5.50562872],
#        [1.14548591]])

# %%
np.arange(4)
# Out:
# array([0, 1, 2, 3])

# %%
dydts=dydt[:,0]
dydts
# Out:
# array([1.        , 4.1207187 , 5.50562872, 1.14548591])
