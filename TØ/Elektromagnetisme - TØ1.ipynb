# %%
x=[1,2,3,4]
sum(x)
# Out:
# 10

# %%
16**2-12*18+2
# Out:
# 42

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.linspace(-10,10,50)
x=x[x!=0]
f=np.sin(x)/x
plt.plot(x,f,color='red')
plt.show()

# %%
from scipy.integrate import quad
y=lambda t: 2*np.sqrt(2)*np.cos(t)-5/(np.pi)
28*quad(y,0,np.pi/4)[0]
# Out:
# 21.0

# %%
f=lambda x: 2*x**(1/3)
quad(f, 0, 12.1722)[0]
# Out:
# 42.00007170368194

# %%
f=lambda x: np.log(1+np.tan(x))
8/np.log(2)*quad(f,0,np.pi/4)[0]
# Out:
# 3.141592653589793
